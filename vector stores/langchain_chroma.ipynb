# %%
# !nvidia-smi
# Out:
# Wed Sep  2 06:40:54 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install torch
import torch

if torch.cuda.is_available():
    print(f"GPU is available: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is NOT available. Running on CPU.")
# Out:
# GPU is available: Tesla T4

# %%
# !pip install -q langchain langchain-google-genai langchain-community chromadb pypdf tiktoken "opentelemetry-api>=1.39,<=1.42.1" "opentelemetry-sdk>=1.39,<=1.42.1" "requests==2.32.4"  # requests==2.32.4 keeps Colab happy; google-auth is intentionally left newer (>=2.56.0) because Gemini needs it
# Out:
# ERROR: Operation cancelled by user

# %%
# !pip install -q langchain langchain-google-genai  # fast — just to get Gemini working

# %%
2526VJO1005937646
